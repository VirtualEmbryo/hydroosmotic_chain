# %%
import numpy as np
import matplotlib.pyplot as plt

import os
import sys

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path :
    sys.path.append(module_path)

    
import _ressources.chain as chain
import _ressources.tools as tools
import _ressources.lumenclass as lc

main_dir = '/Users/mathieuleverge/git/chain_lumen/'

# %%
folder0 = '_data/N1000_firsttrial/N1000_0000/'
folder1 = '_data/N1000_firsttrial/N1000_0001/'
folder2 = '_data/N1000_firsttrial/N1000_0002/'
folder3 = '_data/N1000_firsttrial/N1000_0003/'
folder4 = '_data/N1000_firsttrial/N1000_00034/'

# %%
L0, nions0, pos0 = tl.load_file(os.path.join(folder0, 'sim_all.dat'))
ell0 = tl.load_brfile(os.path.join(folder0, 'sim_bridges.dat'))

# %%
L1, nions1, pos1 = tl.load_file(os.path.join(folder1, 'sim_all.dat'))
ell1 = tl.load_brfile(os.path.join(folder1, 'sim_bridges.dat'))

# %%
L2, nions2, pos2 = tl.load_file(os.path.join(folder2, 'sim_all.dat'))
ell2 = tl.load_brfile(os.path.join(folder2, 'sim_bridges.dat'))

# %%
L3, nions3, pos3 = tl.load_file(os.path.join(folder3, 'sim_all.dat'))
ell3 = tl.load_brfile(os.path.join(folder3, 'sim_bridges.dat'))

# %%
L4, nions4, pos0 = tl.load_file(os.path.join(folder4, 'sim_all.dat'))
ell4 = tl.load_brfile(os.path.join(folder4, 'sim_bridges.dat'))

# %%
tl.plot_evolution(L0, nions0, ell0, savename='chainN10.eps', show_totalarea=False, savefig=0, x_logscale=0, figsize=(8, 8))

# %%
tl.plot_evolution(L1, nions1, ell1, savename='chainN10.eps', show_totalarea=False, savefig=0, x_logscale=0, figsize=(8, 8))

# %%
tl.plot_evolution(L2, nions2, ell2, savename='chainN10.eps', show_totalarea=False, savefig=0, x_logscale=0, figsize=(8, 8))

# %%
tl.plot_evolution(L3, nions3, ell3, savename='chainN10.eps', show_totalarea=False, savefig=0, x_logscale=0, figsize=(8, 8))

# %%
tl.plot_evolution(L4, nions4, ell4, savename='chainN10.eps', show_totalarea=False, savefig=0, x_logscale=0, figsize=(8, 8))

# %%
Nt0 = np.loadtxt(os.path.join(folder0, 'sim_nlum.dat'))

# %%
Nt1 = np.loadtxt(os.path.join(folder1, 'sim_nlum.dat'))

# %%
Nt2 = np.loadtxt(os.path.join(folder2, 'sim_nlum.dat'))

# %%
Nt3 = np.loadtxt(os.path.join(folder3, 'sim_nlum.dat'))

# %%
Nt4 = np.loadtxt(os.path.join(folder4, 'sim_nlum.dat'))

# %%
plt.xscale('log')
plt.yscale('log')
plt.plot(Nt0[:, 0], Nt0[:, 1], marker = '+')
plt.plot(Nt1[:, 0], Nt1[:, 1], marker = '+')

# %%
tstep = L[1:, 0] - L[:-1, 0]
plt.xscale('log')
plt.yscale('log')
plt.plot(L[101:, 0], tstep[100:], marker='+')

# %%
fold = '_data/N1000_0000/'

Nt_1000 = np.loadtxt(os.path.join(main_dir, fold, 'sim_nlum.dat'))

# %%
L1000
# Out:
# array([[0.        , 0.76002319, 1.11014969, ..., 0.98748914, 0.9647577 ,
#         0.66731681]])

# %%
L1000, nions1000, pos1000 = tools.load_file(os.path.join(main_dir, fold, 'sim_all.dat'), max_rows=0)
ell1000 = tools.load_brfile(os.path.join(main_dir, fold, 'sim_bridges.dat'), max_rows=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c5e903eb49ad> in <module>
# ----> 1 L1000, nions1000, pos1000 = tools.load_file(os.path.join(main_dir, fold, 'sim_all.dat'), max_rows=0)
#       2 ell1000 = tools.load_brfile(os.path.join(main_dir, fold, 'sim_bridges.dat'), max_rows=0)
#
# ~/git/chain_lumen/_ressources/tools.py in load_file(filename, max_rows)
#     211         dat = np.loadtxt(filename, max_rows=max_rows)
#     212     else :
# --> 213         dat = np.loadtxt(filename)
#     214
#     215     Nmax = int(np.max(dat[:, 0]))
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1144         # converting the data
#    1145         X = None
# -> 1146         for x in read_data(_loadtxt_chunksize):
# ...

# %%
tools.plot_evolution(L1000[1000:], nions1000[1000:], ell1000[1000:], savename='chainN1000.eps', show_totalarea=False, savefig=0, x_logscale=1, figsize=(8, 8))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-eccfc32ca4a0> in <module>
# ----> 1 tools.plot_evolution(L1000[1000:], nions1000[1000:], ell1000[1000:], savename='chainN1000.eps', show_totalarea=False, savefig=0, x_logscale=1, figsize=(8, 8))
#
# ~/git/chain_lumen/_ressources/tools.py in plot_evolution(L, nions, ell, show_totalarea, savefig, savename, figsize, x_logscale, y_logscale, show_meanlength)
#     326     # LENGTHS
#     327     ax[0, 0].set_title(r'$\ell_{ij}$', fontsize=15)
# --> 328     for k in range(1, len(ell[0])) :
#     329         ax[0, 0].plot(ell[:, 0], ell[:, k], linestyle='--', linewidth=2, label = str(k))
#     330     mean = np.nanmean(ell[:, 1:], axis=1)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.xscale('log')
plt.yscale('log')
plt.plot(Nt_1000[1:, 0], Nt_1000[1:, 1])

# %%
tstep = L1000[1:, 0] - L1000[:-1, 0]
plt.xscale('log')
plt.yscale('log')

start = 20

end = -1

plt.plot(L1000[start+1:end, 0], tstep[start:end], marker='+')

# %%
Nt_1000[-1]
# Out:
# array([7.66558605e-02, 9.44000000e+02])
