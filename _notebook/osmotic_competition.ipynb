# %%
import numpy as np
import matplotlib.pyplot as plt

import os
import sys

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path :
    sys.path.append(module_path)

    
import _ressources.chain as chain
import _ressources.tools as tools
import _ressources.lumenclass as lc

main_dir = '/Users/mathieuleverge/git/chain_lumen/'
data_dir = '_data'

mu = np.sin(np.pi/3.)**2 / (2*np.pi/3. - np.sin(2*np.pi/3.))

# %% [markdown]
# # Osmotic Equilibrium

# %%
show_chain = False
show_area = 1
savefig = 1
x_log = 0

# %% [markdown]
# ## No Screening

# %%
path1 = os.path.join(main_dir, data_dir, 'competition_osmotic/osmotic_eq', 'no_screening')

L_ns, nions_ns, pos_ns = tools.load_file(os.path.join(path1, 'sim_all.dat'))
ell_ns = tools.load_brfile(os.path.join(path1, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path1, 'config.conf'))

if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
# Out:
# Import successful !

# %%
savename_ns = os.path.join(main_dir, '_data/competition_osmotic/osmotic_eq/no_screening/graphs.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=\chi_v=10$ (no screening)'
tools.plot_evolution(L_ns, nions_ns, ell_ns, savename=savename_ns, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# ## Hydraulic Screening

# %%
path2 = os.path.join(main_dir, data_dir, 'competition_osmotic/osmotic_eq', 'hydro_screening')

L_hs, nions_hs, pos_hs = tools.load_file(os.path.join(path2, 'sim_all.dat'))
ell_hs = tools.load_brfile(os.path.join(path2, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path2, 'config.conf'))

if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
# Out:
# Import successful !

# %%
savename_hs = os.path.join(main_dir, '_data/competition_osmotic/osmotic_eq/hydro_screening/graphs.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=10 ; \chi_v=0.1$ (H-screening)'
tools.plot_evolution(L_hs, nions_hs, ell_hs, savename=savename_hs, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# ## Osmotic Screening

# %%
path3 = os.path.join(main_dir, data_dir, 'competition_osmotic/osmotic_eq', 'osm_screening')

L_os, nions_os, pos_os = tools.load_file(os.path.join(path3, 'sim_all.dat'))
ell_os = tools.load_brfile(os.path.join(path3, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path3, 'config.conf'))

if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
# Out:
# Import successful !

# %%
savename_os = os.path.join(main_dir, '_data/competition_osmotic/osmotic_eq/osm_screening/graphs.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=0.1 ; \chi_v=10$ (O-screening)'
tools.plot_evolution(L_os, nions_os, ell_os, savename=savename_os, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# ## Total Screening

# %%
path4 = os.path.join(main_dir, data_dir, 'competition_osmotic/osmotic_eq', 'total_screening')

L_ts, nions_ts, pos_ts = tools.load_file(os.path.join(path4, 'sim_all.dat'))
ell_ts = tools.load_brfile(os.path.join(path4, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path4, 'config.conf'))

if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
# Out:
# Import successful !

# %%
savename_ts = os.path.join(main_dir, '_data/competition_osmotic/osmotic_eq/total_screening/graphs.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=\chi_v=0.1$ (HO-screening)'
tools.plot_evolution(L_ts, nions_ts, ell_ts, savename=savename_ts, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# # Competition
# ## Osmotic Equilibrium

# %%
path5 = os.path.join(main_dir, data_dir, 'competition_osmotic/competition', 'equilibrium')

L_eq, nions_eq, pos_eq = tools.load_file(os.path.join(path5, 'sim_all.dat'))
ell_eq = tools.load_brfile(os.path.join(path5, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path5, 'config.conf'))

show_chain=1
if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
show_chain=0
# Out:
# Import successful !
# Import config from /Users/mathieuleverge/git/chain_lumen/_data/competition_osmotic/competition/config/equilibrium_config
# ======= CHAIN =======
# Type         : hydroosmotic
# Total length : 11.4
# Current Time : 0
# Screening lengths :
#         xi_s = 23.333333333333336
#         xi_v = 23.333333333333336
# Permeation times :
#        tau_s = 1.0
#        tau_v = 1.0
# Pumping : None
# ======= LUMENS =======
# Nb lumens : 2
# Lumen 0 is at position 0.000 with length 0.000 and 0.000 ions with pumping 0.000
# Lumen 1 is at position 4.000 with length 1.000 and 1.638 ions with pumping 0.000
# Lumen 2 is at position 7.200 with length 1.200 and 2.358 ions with pumping 0.000
# Lumen -1 is at position 11.400 with length 0.000 and 0.000 ions with pumping 0.000
# ======= BRIDGES ======
# Bridge 0 : (0, 1) has length 3.0 with pumping 0.000
# Bridge 1 : (1, 2) has length 1.0 with pumping 0.000
# Bridge 2 : (2, -1) has length 3.0 with pumping 0.000

# %%
savename_eq = os.path.join(main_dir, '_data/competition_osmotic/competition/equilibrium/graph.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=\chi_v=10$ at osmotic equilibrium'
tools.plot_evolution(L_eq, nions_eq, ell_eq, savename=savename_eq, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# ## Increasing the concentration in lumen 2

# %%
path6 = os.path.join(main_dir, data_dir, 'competition_osmotic/competition', 'N_increase')

L_N, nions_N, pos_N = tools.load_file(os.path.join(path6, 'sim_all.dat'))
ell_N = tools.load_brfile(os.path.join(path6, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path6, 'config.conf'))

show_chain=1
if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
show_chain=0
# Out:
# Import successful !
# Import config from /Users/mathieuleverge/git/chain_lumen/_data/competition_osmotic/competition/config/N_increase_config
# ======= CHAIN =======
# Type         : hydroosmotic
# Total length : 11.4
# Current Time : 0
# Screening lengths :
#         xi_s = 23.333333333333336
#         xi_v = 23.333333333333336
# Permeation times :
#        tau_s = 1.0
#        tau_v = 1.0
# Pumping : None
# ======= LUMENS =======
# Nb lumens : 2
# Lumen 0 is at position 0.000 with length 0.000 and 0.000 ions with pumping 0.000
# Lumen 1 is at position 4.000 with length 1.000 and 3.276 ions with pumping 0.000
# Lumen 2 is at position 7.200 with length 1.200 and 2.358 ions with pumping 0.000
# Lumen -1 is at position 11.400 with length 0.000 and 0.000 ions with pumping 0.000
# ======= BRIDGES ======
# Bridge 0 : (0, 1) has length 3.0 with pumping 0.000
# Bridge 1 : (1, 2) has length 1.0 with pumping 0.000
# Bridge 2 : (2, -1) has length 3.0 with pumping 0.000

# %%
savename_N = os.path.join(main_dir, '_data/competition_osmotic/competition/N_increase/graph.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=\chi_v=10$ with $N_2 < N_1 = 2 N_{1, eq}$'
tools.plot_evolution(L_N, nions_N, ell_N, savename=savename_N, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# ## Decreasing $\chi_s$

# %%
path7 = os.path.join(main_dir, data_dir, 'competition_osmotic/competition', 'chis_decrease')

L_chis, nions_chis, pos_chis = tools.load_file(os.path.join(path7, 'sim_all.dat'))
ell_chis = tools.load_brfile(os.path.join(path7, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path7, 'config.conf'))

show_chain=1
if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
show_chain=0
# Out:
# Import successful !
# Import config from /Users/mathieuleverge/git/chain_lumen/_data/competition_osmotic/competition/config/chis_decrease_config
# ======= CHAIN =======
# Type         : hydroosmotic
# Total length : 11.4
# Current Time : 0
# Screening lengths :
#         xi_s = 0.23333333333333336
#         xi_v = 23.333333333333336
# Permeation times :
#        tau_s = 1.0
#        tau_v = 1.0
# Pumping : None
# ======= LUMENS =======
# Nb lumens : 2
# Lumen 0 is at position 0.000 with length 0.000 and 0.000 ions with pumping 0.000
# Lumen 1 is at position 4.000 with length 1.000 and 1.638 ions with pumping 0.000
# Lumen 2 is at position 7.200 with length 1.200 and 2.358 ions with pumping 0.000
# Lumen -1 is at position 11.400 with length 0.000 and 0.000 ions with pumping 0.000
# ======= BRIDGES ======
# Bridge 0 : (0, 1) has length 3.0 with pumping 0.000
# Bridge 1 : (1, 2) has length 1.0 with pumping 0.000
# Bridge 2 : (2, -1) has length 3.0 with pumping 0.000

# %%
savename_chis = os.path.join(main_dir, '_data/competition_osmotic/competition/chis_decrease/graph.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=0.1 ; \chi_v=10$ at osmotic equilibrium'
tools.plot_evolution(L_chis, nions_chis, ell_chis, savename=savename_chis, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)

# %% [markdown]
# ## Decreasing $\chi_s$ and increasing $N$

# %%
path8 = os.path.join(main_dir, data_dir, 'competition_osmotic/competition', 'N_increase_chis_decrease')

L_chis_N, nions_chis_N, pos_chis_N = tools.load_file(os.path.join(path8, 'sim_all.dat'))
ell_chis_N = tools.load_brfile(os.path.join(path8, 'sim_bridges.dat'))

conf, ch = chain.load_config(os.path.join(path8, 'config.conf'))

show_chain=1
if show_chain :
    print(ch)
    x = np.linspace(0, ch.total_length, 1001)
    tools.plot_profile(x, ch, centers=0, lw=1.5, show=True)
show_chain=0


savename_chis_N = os.path.join(main_dir, '_data/competition_osmotic/competition/N_increase_chis_decrease/graph.eps')

title = 'HO-Chain of 2 lumens, $\chi_s=0.1 ; \chi_v=10$ with $N_2 < N_1 = 2N_{1, eq}$'
tools.plot_evolution(L_chis_N, nions_chis_N, ell_chis_N, savename=savename_chis_N, show_totalarea=show_area, savefig=savefig, x_logscale=x_log, figsize=(8, 8), title=title)
# Out:
# Import successful !
# Import config from /Users/mathieuleverge/git/chain_lumen/_data/competition_osmotic/competition/config/N_increase_chis_decrease_config
# ======= CHAIN =======
# Type         : hydroosmotic
# Total length : 11.4
# Current Time : 0
# Screening lengths :
#         xi_s = 0.23333333333333336
#         xi_v = 23.333333333333336
# Permeation times :
#        tau_s = 1.0
#        tau_v = 1.0
# Pumping : None
# ======= LUMENS =======
# Nb lumens : 2
# Lumen 0 is at position 0.000 with length 0.000 and 0.000 ions with pumping 0.000
# Lumen 1 is at position 4.000 with length 1.000 and 3.276 ions with pumping 0.000
# Lumen 2 is at position 7.200 with length 1.200 and 2.358 ions with pumping 0.000
# Lumen -1 is at position 11.400 with length 0.000 and 0.000 ions with pumping 0.000
# ======= BRIDGES ======
# Bridge 0 : (0, 1) has length 3.0 with pumping 0.000
# Bridge 1 : (1, 2) has length 1.0 with pumping 0.000
# Bridge 2 : (2, -1) has length 3.0 with pumping 0.000
